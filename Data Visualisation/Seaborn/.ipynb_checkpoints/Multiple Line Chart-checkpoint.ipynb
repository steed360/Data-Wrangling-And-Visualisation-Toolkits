# %% [markdown]
# ##  Multiple Line Charts

# %%
# Try to use Seaborn/Matplotlib to replicate another cool viz from Cole Nusaumbber Knaflic's book Storytelling with Data.
# Inspiration from :
# https://github.com/adamribaudo/storytelling-with-data-ggplot
# Using code from the excellent:
# https://github.com/empathy87/storytelling-with-data

## Import libraries
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
from matplotlib import transforms
import pandas as pd
import seaborn as sns
from matplotlib.ticker import FixedLocator, FixedFormatter

# %%
# define colors
GRAY1, GRAY2, GRAY3 = '#231F20', '#414040', '#555655'
GRAY4, GRAY5, GRAY6 = '#646369', '#76787B', '#828282'
GRAY7, GRAY8, GRAY9 = '#929497', '#A6A6A5', '#BFBEBE'
BLUE1, BLUE2, BLUE3, BLUE4 = '#174A7E', '#4A81BF', '#94B2D7', '#94AFC5'
BLUE5, BLUE6 = '#92CDDD', '#2E869D'
RED1, RED2 = '#C3514E', '#E6BAB7'
GREEN1, GREEN2 = '#0C8040', '#9ABB59'
ORANGE1, ORANGE2, ORANGE3 = '#F79747', '#FAC090', '#F36721'

# %%
# configure plot font family to Arial
plt.rcParams['font.family'] = 'Arial'
# configure mathtext bold and italic font family to Arial
matplotlib.rcParams['mathtext.fontset'] = 'custom'
matplotlib.rcParams['mathtext.bf'] = 'Arial:bold'
matplotlib.rcParams['mathtext.it'] = 'Arial:italic'

# %% [markdown]
# #### Dummy Data

# %%
import seaborn as sns


flights = sns.load_dataset("flights")
flights = df[df.year>= 1957].sort_index (ascending = False)


# Plot each year's time series in its own facet
g = sns.relplot(
    data=flights,
    x="month", y="passengers", col="year" ,  #hue=BLUE1,
    kind="line"  ,color=BLUE1
    , linewidth=3, zorder=5,
    col_wrap=1 , height=1.9, aspect=4.5, legend=False
)

sns.despine (bottom=True, left=True)

# Iterate over each subplot to customize further
for year, ax in g.axes_dict.items():

    # Add the title as an annotation within the plot
    ax.text(-0.15, .45, year, transform=ax.transAxes, color=GRAY5, fontsize=16)#  fontweight="bold")

    # Plot every year's time series in the background
    sns.lineplot(
        data=flights, x="month", y="passengers", units="year",
        estimator=None, color=".7", linewidth=2, ax=ax,
    )

    # One way to turn off y axis labels :(
    ax.tick_params (axis='y', width=0 ,labelsize=0, colors=GRAY5)
    ax.tick_params (axis='x', width=0 ,labelsize=0, colors=GRAY5)

    # Add in the axis spine for the last 
    if year == 1957:

        ax.spines['top'].set_visible(True)
        ax.tick_params (axis='x', width=1 ,labelsize=17, colors=GRAY7, labeltop=True, labelcolor=GRAY5)
        #ax.tick_params (axis='x',  labelbottom=False)
    
    # Add in points at either end.
    x = [0, 11] 
    y = [int (flights.loc [np.logical_and ( flights.year==year , flights.month=='Jan' ), 'passengers']) , 
         int (flights.loc [np.logical_and ( flights.year==year , flights.month=='Dec' ), 'passengers']) ]    

    sns.scatterplot(x=x, y=y, color=BLUE1, s=200, ax=ax)
    ax.text ( x[0]-0.9, y[0], y[0], color=BLUE1, fontsize=18 )
    ax.text ( x[1]+0.2, y[1], y[1], color=BLUE1, fontsize=18 )
    
# Reduce the frequency of the x axis ticks
ax.set_xticks(ax.get_xticks()[::2])

# Tweak the supporting aspects of the plot
g.set_titles("")
g.set_axis_labels("", "")
g.tight_layout()

g.fig.subplots_adjust(top=0.85) # adjust the Figure in rp
g.fig.suptitle('Consistent Increase in Flight Demand', fontsize=17)
# Out:
# Text(0.5, 0.98, 'Consistent Increase in Flight Demand')
